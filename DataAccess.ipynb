# %%
# Import necessary libraries
import os
import re
import pandas as pd
import geopandas as gpd
import leafmap.foliumap as leafmap
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from zipfile import ZipFile

# %%
# Define the names of the directories to be created
data_folder = 'data'
output_folder = 'output'

# Check if the directory exists; if not, create it
if not os.path.exists(data_folder):
    os.mkdir(data_folder)
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
# Function to download data
def download(url):
    filename = os.path.join(data_folder, os.path.basename(url))
    if not os.path.exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)


# Call the download function with the specified URL
download('https://github.com/spatialthoughts/python-tutorials/raw/main/data/' +
         'Hurricane_Evacuation_Centers.xlsx')

# %%
# Load hurricane evacuation center data
excel_file = 'Hurricane_Evacuation_Centers.xlsx'
excel_file_path = os.path.join(data_folder, excel_file)
address_df = pd.read_excel(excel_file_path, skiprows=[0])
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
# [64 rows x 7 columns]

# %%
def make_ordinal(match):
    n = int(match.group(1))
    if 11 <= (n % 100) <= 13:
        suffix = 'th'
    else:
        suffix = ['th', 'st', 'nd', 'rd', 'th'][min(n % 10, 4)]
    return str(n) + suffix + match.group(2)

def update_address(row):
  old_address = row['ADDRESS']
  pattern = r'(\d+)(\s+(?:Street|Avenue|Blvd|Drive))'
  result = re.sub(pattern, make_ordinal, old_address)
  return result

address_df['ADDRESS_FIXED'] = address_df.apply(update_address, axis=1)
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
# [64 rows x 8 columns]

# %%
address_df['Full_Address'] = (
    address_df['ADDRESS_FIXED'] + ',' +
    'NYC' + ',' +
    address_df['STATE']+ ',' +
    address_df['ZIP_CODE'].astype(str))
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED  \
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
#                                          Full_Address
# 0                      147-26 25th Drive,NYC,NY,11354
# 1                       141 Macon Street,NYC,NY,11216
# 2                         544 7th Avenue,NYC,NY,11215
# 3                  2780 Reservoir Avenue,NYC,NY,10468
# 4                        7002 4th Avenue,NYC,NY,11209
# ..                                                ...
# 59                     730 Bryant Avenue,NYC,NY,10474
# 60                    2760 Briggs Avenue,NYC,NY,10458
# 61                     45-30 36th Street,NYC,NY,11101
# 62                    1827 Archer Street,NYC,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453
#
# [64 rows x 9 columns]

# %%
from tqdm.notebook import tqdm

tqdm.pandas()

locator = Nominatim(user_agent='spatialthoughts', timeout=10)
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

address_df_pd = address_df.copy()
address_df_pd['location'] = address_df_pd['Full_Address'].progress_apply(geocode)
address_df_pd
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED  \
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
#                                          Full_Address  \
# 0                      147-26 25th Drive,NYC,NY,11354
# 1                       141 Macon Street,NYC,NY,11216
# 2                         544 7th Avenue,NYC,NY,11215
# 3                  2780 Reservoir Avenue,NYC,NY,10468
# 4                        7002 4th Avenue,NYC,NY,11209
# ..                                                ...
# 59                     730 Bryant Avenue,NYC,NY,10474
# 60                    2760 Briggs Avenue,NYC,NY,10458
# 61                     45-30 36th Street,NYC,NY,11101
# 62                    1827 Archer Street,NYC,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453
#
#                                              location
# 0   (147-26, 25th Drive, Linden Hill, Queens, City...
# 1   (Junior High School 258, 141, Macon Street, Be...
# 2   (544, 7th Avenue, South Slope, Brooklyn, Kings...
# 3   (2780, Reservoir Avenue, Kingsbridge Heights, ...
# 4   (7002, 4th Avenue, Bay Ridge, Brooklyn, Kings ...
# ..                                                ...
# 59  (730, Bryant Avenue, Hunts Point, Bronx County...
# 60  (2760, Briggs Avenue, Bedford Park, Bronx Coun...
# 61  (45-30, 36th Street, Sunnyside, Queens County,...
# 62  (Public School 102, 1827, Archer Street, Bronx...
# 63  (East 125th Street, East Harlem, Manhattan, Ne...
#
# [64 rows x 10 columns]

# %%
address_df_pd['latitude'] = address_df_pd['location'].apply(lambda loc: loc.latitude if loc else None)
address_df_pd['longitude'] = address_df_pd['location'].apply(lambda loc: loc.longitude if loc else None)
address_df_pd
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED  \
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
#                                          Full_Address  \
# 0                      147-26 25th Drive,NYC,NY,11354
# 1                       141 Macon Street,NYC,NY,11216
# 2                         544 7th Avenue,NYC,NY,11215
# 3                  2780 Reservoir Avenue,NYC,NY,10468
# 4                        7002 4th Avenue,NYC,NY,11209
# ..                                                ...
# 59                     730 Bryant Avenue,NYC,NY,10474
# 60                    2760 Briggs Avenue,NYC,NY,10458
# 61                     45-30 36th Street,NYC,NY,11101
# 62                    1827 Archer Street,NYC,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453
#
#                                              location   latitude  longitude
# 0   (147-26, 25th Drive, Linden Hill, Queens, City...  40.774893 -73.818642
# 1   (Junior High School 258, 141, Macon Street, Be...  40.681918 -73.945597
# 2   (544, 7th Avenue, South Slope, Brooklyn, Kings...  40.660181 -73.987930
# 3   (2780, Reservoir Avenue, Kingsbridge Heights, ...  40.870261 -73.896569
# 4   (7002, 4th Avenue, Bay Ridge, Brooklyn, Kings ...  40.633625 -74.024038
# ..                                                ...        ...        ...
# 59  (730, Bryant Avenue, Hunts Point, Bronx County...  40.816040 -73.885264
# 60  (2760, Briggs Avenue, Bedford Park, Bronx Coun...  40.867779 -73.890245
# 61  (45-30, 36th Street, Sunnyside, Queens County,...  40.743475 -73.929464
# 62  (Public School 102, 1827, Archer Street, Bronx...  40.838106 -73.865790
# 63  (East 125th Street, East Harlem, Manhattan, Ne...  40.802709 -73.933445
#
# [64 rows x 12 columns]

# %%
failed = address_df_pd[address_df_pd['location'].isna()]
failed
# Out:
#         CITY              EC_Name           ADDRESS  ZIP_CODE  BOROCODE STATE  \
# 54  New York  P.S. 48 - Manhattan  4360-78 Broadway     10033         1    NY
#
#    ACCESSIBLE     ADDRESS_FIXED                   Full_Address location  \
# 54          Y  4360-78 Broadway  4360-78 Broadway,NYC,NY,10033     None
#
#     latitude  longitude
# 54       NaN        NaN

# %%
address_df_pd.loc[54, ['latitude', 'longitude']] = (40.85339,-73.93350)

# %%
address_df_pd = address_df_pd[['EC_Name', 'Full_Address', 'latitude', 'longitude']]
address_df_pd.rename(columns = {'EC_Name': 'Name', 'Full_Address': 'Address'}, inplace=True)

# %%
geometry = gpd.points_from_xy(address_df_pd.longitude, address_df_pd.latitude)
address_gdf = gpd.GeoDataFrame(address_df_pd, crs='EPSG:4326', geometry=geometry)
address_gdf
# Out:
#                                           Name  \
# 0                          J.H.S. 185 - Queens
# 1                          I.S. 258 - Brooklyn
# 2                           I.S. 88 - Brooklyn
# 3                                Walton HS - X
# 4   P.S./I.S.30 Mary White Ovington - Brooklyn
# ..                                         ...
# 59                            I.S. 201 - Bronx
# 60                             P.S. 46 - Bronx
# 61                             Aviation HS - Q
# 62                            P.S. 102 - Bronx
# 63  Morris Heights Educational Complex - Bronx
#
#                                               Address   latitude  longitude  \
# 0                      147-26 25th Drive,NYC,NY,11354  40.774893 -73.818642
# 1                       141 Macon Street,NYC,NY,11216  40.681918 -73.945597
# 2                         544 7th Avenue,NYC,NY,11215  40.660181 -73.987930
# 3                  2780 Reservoir Avenue,NYC,NY,10468  40.870261 -73.896569
# 4                        7002 4th Avenue,NYC,NY,11209  40.633625 -74.024038
# ..                                                ...        ...        ...
# 59                     730 Bryant Avenue,NYC,NY,10474  40.816040 -73.885264
# 60                    2760 Briggs Avenue,NYC,NY,10458  40.867779 -73.890245
# 61                     45-30 36th Street,NYC,NY,11101  40.743475 -73.929464
# 62                    1827 Archer Street,NYC,NY,10460  40.838106 -73.865790
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453  40.802709 -73.933445
#
#                       geometry
# 0   POINT (-73.81864 40.77489)
# 1   POINT (-73.94560 40.68192)
# 2   POINT (-73.98793 40.66018)
# 3   POINT (-73.89657 40.87026)
# 4   POINT (-74.02404 40.63362)
# ..                         ...
# 59  POINT (-73.88526 40.81604)
# 60  POINT (-73.89025 40.86778)
# 61  POINT (-73.92946 40.74347)
# 62  POINT (-73.86579 40.83811)
# 63  POINT (-73.93344 40.80271)
#
# [64 rows x 5 columns]

# %%
import folium
m = leafmap.Map(width=800, height=500)
address_gdf.explore(
    m=m,
    marker_type='marker',
    marker_kwds={
        'icon': folium.Icon(color='#fdbb84', icon='hurricane', prefix='fa')
    }
)
m.zoom_to_gdf(address_gdf)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eabd6e667eb312ced70bae367cfb1bd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eabd6e667eb312ced70bae367cfb1bd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eabd6e667eb312ced70bae367cfb1bd2 = L.map(
#                 &quot;map_eabd6e667eb312ced70bae367cfb1bd2&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_eabd6e667eb312ced70bae367cfb1bd2);
#
#
#
#
#
#             var tile_layer_eed14c234ab3bf933a7f76a0391fde4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eed14c234ab3bf933a7f76a0391fde4b.addTo(map_eabd6e667eb312ced70bae367cfb1bd2);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_eabd6e667eb312ced70bae367cfb1bd2);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_6ad5cd2862bcc8b705a201cbef79a2b0 = new L.featureGroup().addTo(
#                 map_eabd6e667eb312ced70bae367cfb1bd2
#             );
#             options.edit.featureGroup = drawnItems_draw_control_6ad5cd2862bcc8b705a201cbef79a2b0;
#             var draw_control_6ad5cd2862bcc8b705a201cbef79a2b0 = new L.Control.Draw(
#                 options
#             ).addTo( map_eabd6e667eb312ced70bae367cfb1bd2 );
#             map_eabd6e667eb312ced70bae367cfb1bd2.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_6ad5cd2862bcc8b705a201cbef79a2b0.addLayer(layer);
#              });
#             map_eabd6e667eb312ced70bae367cfb1bd2.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_6ad5cd2862bcc8b705a201cbef79a2b0.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_51bbfca4e762a96b20e657aafd663325 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_eabd6e667eb312ced70bae367cfb1bd2.addControl(measure_control_51bbfca4e762a96b20e657aafd663325);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({

# %%
output_file = 'hurricane_evacuation_centers.shp'
output_path = os.path.join(output_folder, output_file)

address_gdf.to_file(filename=output_path)

# %%
output_zip_file = 'hurricane_evacuation_centers.zip'
output_zip_path = os.path.join(output_folder, output_zip_file)

sidecar_files = [
    os.path.join(output_folder, file)
    for file in os.listdir(output_folder)
    if file.endswith(('shp', 'shx', 'dbf', 'prj'))
]

with ZipFile(output_zip_path, 'w') as zip_object:
    for sidecar in sidecar_files:
      zip_object.write(sidecar, os.path.basename(sidecar))
